# %%
# %matplotlib inline
from matplotlib import style
style.use('fivethirtyeight')
import matplotlib.pyplot as plt
from sqlalchemy import column

# %%
import numpy as np
import pandas as pd

# %%
import datetime as dt

# %% [markdown]
# # Reflect Tables into SQLAlchemy ORM

# %%
# Python SQL toolkit and Object Relational Mapper
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func, inspect, desc

# %%
engine = create_engine("sqlite:///Resources/hawaii.sqlite")

# %%
# reflect an existing database into a new model
Base = automap_base()
# reflect the tables
Base.prepare(engine, reflect=True)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/engine/base.py in _wrap_pool_connect(self, fn, connection)
#    2274         try:
# -> 2275             return fn()
#    2276         except dialect.dbapi.Error as e:
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/pool/base.py in unique_connection(self)
#     302         """
# --> 303         return _ConnectionFairy._checkout(self)
#     304
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/pool/base.py in _checkout(cls, pool, threadconns, fairy)
#     759         if not fairy:
# --> 760             fairy = _ConnectionRecord.checkout(pool)
#     761
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/pool/base.py in checkout(cls, pool)
#     491     def checkout(cls, pool):
# --> 492         rec = pool._do_get()
#     493         try:
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/pool/impl.py in _do_get(self)
#     237     def _do_get(self):
# --> 238         return self._create_connection()
#     239
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/pool/base.py in _create_connection(self)
#     307
# --> 308         return _ConnectionRecord(self)
#     309
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/pool/base.py in __init__(self, pool, connect)
#     436         if connect:
# --> 437             self.__connect(first_connect_check=True)
#     438         self.finalize_callback = deque()
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/pool/base.py in __connect(self, first_connect_check)
#     638             self.starttime = time.time()
# --> 639             connection = pool._invoke_creator(self)
#     640             pool.logger.debug("Created new connection %r", connection)
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/engine/strategies.py in connect(connection_record)
#     113                             return connection
# --> 114                 return dialect.connect(*cargs, **cparams)
#     115
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/engine/default.py in connect(self, *cargs, **cparams)
#     480     def connect(self, *cargs, **cparams):
# --> 481         return self.dbapi.connect(*cargs, **cparams)
#     482
#
# OperationalError: unable to open database file
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# <ipython-input-68-f6a23d3d2a7f> in <module>
#       2 Base = automap_base()
#       3 # reflect the tables
# ----> 4 Base.prepare(engine, reflect=True)
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/ext/automap.py in prepare(cls, engine, reflect, schema, classname_for_table, collection_class, name_for_scalar_relationship, name_for_collection_relationship, generate_relationship)
#     760                 schema=schema,
#     761                 extend_existing=True,
# --> 762                 autoload_replace=False,
#     763             )
#     764
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/sql/schema.py in reflect(self, bind, schema, views, only, extend_existing, autoload_replace, resolve_fks, **dialect_kwargs)
#    4194             bind = _bind_or_error(self)
#    4195
# -> 4196         with bind.connect() as conn:
#    4197
#    4198             reflect_opts = {
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/engine/base.py in connect(self, **kwargs)
#    2204         """
#    2205
# -> 2206         return self._connection_cls(self, **kwargs)
#    2207
#    2208     @util.deprecated(
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/engine/base.py in __init__(self, engine, connection, close_with_result, _branch_from, _execution_options, _dispatch, _has_events)
#     101                 connection
#     102                 if connection is not None
# --> 103                 else engine.raw_connection()
#     104             )
#     105             self.__transaction = None
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/engine/base.py in raw_connection(self, _connection)
#    2304         """
#    2305         return self._wrap_pool_connect(
# -> 2306             self.pool.unique_connection, _connection
#    2307         )
#    2308
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/engine/base.py in _wrap_pool_connect(self, fn, connection)
#    2277             if connection is None:
#    2278                 Connection._handle_dbapi_exception_noconnection(
# -> 2279                     e, dialect, self
#    2280                 )
#    2281             else:
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/engine/base.py in _handle_dbapi_exception_noconnection(cls, e, dialect, engine)
#    1542             util.raise_from_cause(newraise, exc_info)
#    1543         elif should_wrap:
# -> 1544             util.raise_from_cause(sqlalchemy_exception, exc_info)
#    1545         else:
#    1546             util.reraise(*exc_info)
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/util/compat.py in raise_from_cause(exception, exc_info)
#     396     exc_type, exc_value, exc_tb = exc_info
#     397     cause = exc_value if exc_value is not exception else None
# --> 398     reraise(type(exception), exception, tb=exc_tb, cause=cause)
#     399
#     400
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/util/compat.py in reraise(tp, value, tb, cause)
#     150             value.__cause__ = cause
#     151         if value.__traceback__ is not tb:
# --> 152             raise value.with_traceback(tb)
#     153         raise value
#     154
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/engine/base.py in _wrap_pool_connect(self, fn, connection)
#    2273         dialect = self.dialect
#    2274         try:
# -> 2275             return fn()
#    2276         except dialect.dbapi.Error as e:
#    2277             if connection is None:
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/pool/base.py in unique_connection(self)
#     301
#     302         """
# --> 303         return _ConnectionFairy._checkout(self)
#     304
#     305     def _create_connection(self):
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/pool/base.py in _checkout(cls, pool, threadconns, fairy)
#     758     def _checkout(cls, pool, threadconns=None, fairy=None):
#     759         if not fairy:
# --> 760             fairy = _ConnectionRecord.checkout(pool)
#     761
#     762             fairy._pool = pool
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/pool/base.py in checkout(cls, pool)
#     490     @classmethod
#     491     def checkout(cls, pool):
# --> 492         rec = pool._do_get()
#     493         try:
#     494             dbapi_connection = rec.get_connection()
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/pool/impl.py in _do_get(self)
#     236
#     237     def _do_get(self):
# --> 238         return self._create_connection()
#     239
#     240     def recreate(self):
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/pool/base.py in _create_connection(self)
#     306         """Called by subclasses to create a new ConnectionRecord."""
#     307
# --> 308         return _ConnectionRecord(self)
#     309
#     310     def _invalidate(self, connection, exception=None, _checkin=True):
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/pool/base.py in __init__(self, pool, connect)
#     435         self.__pool = pool
#     436         if connect:
# --> 437             self.__connect(first_connect_check=True)
#     438         self.finalize_callback = deque()
#     439
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/pool/base.py in __connect(self, first_connect_check)
#     637         try:
#     638             self.starttime = time.time()
# --> 639             connection = pool._invoke_creator(self)
#     640             pool.logger.debug("Created new connection %r", connection)
#     641             self.connection = connection
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/engine/strategies.py in connect(connection_record)
#     112                         if connection is not None:
#     113                             return connection
# --> 114                 return dialect.connect(*cargs, **cparams)
#     115
#     116             creator = pop_kwarg("creator", connect)
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/engine/default.py in connect(self, *cargs, **cparams)
#     479
#     480     def connect(self, *cargs, **cparams):
# --> 481         return self.dbapi.connect(*cargs, **cparams)
#     482
#     483     def create_connect_args(self, url):
#
# OperationalError: (sqlite3.OperationalError) unable to open database file
# (Background on this error at: http://sqlalche.me/e/e3q8)

# %%
# We can view all of the classes that automap found the table names
Base.classes.keys()
# Out:
# []

# %%
# Save references to each table
Measurement = Base.classes.measurement
Station = Base.classes.station
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/util/_collections.py in __getattr__(self, key)
#     209         try:
# --> 210             return self._data[key]
#     211         except KeyError:
#
# KeyError: 'measurement'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# <ipython-input-40-a85ad09ce628> in <module>
#       1 # Save references to each table
# ----> 2 Measurement = Base.classes.measurement
#       3 Station = Base.classes.station
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/util/_collections.py in __getattr__(self, key)
#     210             return self._data[key]
#     211         except KeyError:
# --> 212             raise AttributeError(key)
#     213
#     214     def __contains__(self, key):
#
# AttributeError: measurement

# %%
from sqlalchemy.orm import session

# %%
# Create our session (link) from Python to the DB
session = Session(engine)

# %%
# we will get the table info using the get function
inspector = inspect(engine)
columns = inspector.get_columns('Measurement')
for color in columns:
    print(color['name'], color['type'])
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/engine/base.py in _wrap_pool_connect(self, fn, connection)
#    2274         try:
# -> 2275             return fn()
#    2276         except dialect.dbapi.Error as e:
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/pool/base.py in unique_connection(self)
#     302         """
# --> 303         return _ConnectionFairy._checkout(self)
#     304
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/pool/base.py in _checkout(cls, pool, threadconns, fairy)
#     759         if not fairy:
# --> 760             fairy = _ConnectionRecord.checkout(pool)
#     761
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/pool/base.py in checkout(cls, pool)
#     491     def checkout(cls, pool):
# --> 492         rec = pool._do_get()
#     493         try:
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/pool/impl.py in _do_get(self)
#     237     def _do_get(self):
# --> 238         return self._create_connection()
#     239
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/pool/base.py in _create_connection(self)
#     307
# --> 308         return _ConnectionRecord(self)
#     309
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/pool/base.py in __init__(self, pool, connect)
#     436         if connect:
# --> 437             self.__connect(first_connect_check=True)
#     438         self.finalize_callback = deque()
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/pool/base.py in __connect(self, first_connect_check)
#     638             self.starttime = time.time()
# --> 639             connection = pool._invoke_creator(self)
#     640             pool.logger.debug("Created new connection %r", connection)
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/engine/strategies.py in connect(connection_record)
#     113                             return connection
# --> 114                 return dialect.connect(*cargs, **cparams)
#     115
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/engine/default.py in connect(self, *cargs, **cparams)
#     480     def connect(self, *cargs, **cparams):
# --> 481         return self.dbapi.connect(*cargs, **cparams)
#     482
#
# OperationalError: unable to open database file
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# <ipython-input-43-2c727f6b6fa7> in <module>
#       1 # we will get the table info using the get function
# ----> 2 inspector = inspect(engine)
#       3 columns = inspector.get_columns('Measurement')
#       4 for color in columns:
#       5     print(color['name'], color['type'])
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/inspection.py in inspect(subject, raiseerr)
#      61             if reg is True:
#      62                 return subject
# ---> 63             ret = reg(subject)
#      64             if ret is not None:
#      65                 break
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/engine/reflection.py in _insp(bind)
#     139     @inspection._inspects(Connectable)
#     140     def _insp(bind):
# --> 141         return Inspector.from_engine(bind)
#     142
#     143     @property
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/engine/reflection.py in from_engine(cls, bind)
#     135         if hasattr(bind.dialect, "inspector"):
#     136             return bind.dialect.inspector(bind)
# --> 137         return Inspector(bind)
#     138
#     139     @inspection._inspects(Connectable)
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/engine/reflection.py in __init__(self, bind)
#     109         if self.engine is bind:
#     110             # if engine, ensure initialized
# --> 111             bind.connect().close()
#     112
#     113         self.dialect = self.engine.dialect
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/engine/base.py in connect(self, **kwargs)
#    2204         """
#    2205
# -> 2206         return self._connection_cls(self, **kwargs)
#    2207
#    2208     @util.deprecated(
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/engine/base.py in __init__(self, engine, connection, close_with_result, _branch_from, _execution_options, _dispatch, _has_events)
#     101                 connection
#     102                 if connection is not None
# --> 103                 else engine.raw_connection()
#     104             )
#     105             self.__transaction = None
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/engine/base.py in raw_connection(self, _connection)
#    2304         """
#    2305         return self._wrap_pool_connect(
# -> 2306             self.pool.unique_connection, _connection
#    2307         )
#    2308
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/engine/base.py in _wrap_pool_connect(self, fn, connection)
#    2277             if connection is None:
#    2278                 Connection._handle_dbapi_exception_noconnection(
# -> 2279                     e, dialect, self
#    2280                 )
#    2281             else:
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/engine/base.py in _handle_dbapi_exception_noconnection(cls, e, dialect, engine)
#    1542             util.raise_from_cause(newraise, exc_info)
#    1543         elif should_wrap:
# -> 1544             util.raise_from_cause(sqlalchemy_exception, exc_info)
#    1545         else:
#    1546             util.reraise(*exc_info)
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/util/compat.py in raise_from_cause(exception, exc_info)
#     396     exc_type, exc_value, exc_tb = exc_info
#     397     cause = exc_value if exc_value is not exception else None
# --> 398     reraise(type(exception), exception, tb=exc_tb, cause=cause)
#     399
#     400
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/util/compat.py in reraise(tp, value, tb, cause)
#     150             value.__cause__ = cause
#     151         if value.__traceback__ is not tb:
# --> 152             raise value.with_traceback(tb)
#     153         raise value
#     154
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/engine/base.py in _wrap_pool_connect(self, fn, connection)
#    2273         dialect = self.dialect
#    2274         try:
# -> 2275             return fn()
#    2276         except dialect.dbapi.Error as e:
#    2277             if connection is None:
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/pool/base.py in unique_connection(self)
#     301
#     302         """
# --> 303         return _ConnectionFairy._checkout(self)
#     304
#     305     def _create_connection(self):
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/pool/base.py in _checkout(cls, pool, threadconns, fairy)
#     758     def _checkout(cls, pool, threadconns=None, fairy=None):
#     759         if not fairy:
# --> 760             fairy = _ConnectionRecord.checkout(pool)
#     761
#     762             fairy._pool = pool
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/pool/base.py in checkout(cls, pool)
#     490     @classmethod
#     491     def checkout(cls, pool):
# --> 492         rec = pool._do_get()
#     493         try:
#     494             dbapi_connection = rec.get_connection()
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/pool/impl.py in _do_get(self)
#     236
#     237     def _do_get(self):
# --> 238         return self._create_connection()
#     239
#     240     def recreate(self):
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/pool/base.py in _create_connection(self)
#     306         """Called by subclasses to create a new ConnectionRecord."""
#     307
# --> 308         return _ConnectionRecord(self)
#     309
#     310     def _invalidate(self, connection, exception=None, _checkin=True):
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/pool/base.py in __init__(self, pool, connect)
#     435         self.__pool = pool
#     436         if connect:
# --> 437             self.__connect(first_connect_check=True)
#     438         self.finalize_callback = deque()
#     439
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/pool/base.py in __connect(self, first_connect_check)
#     637         try:
#     638             self.starttime = time.time()
# --> 639             connection = pool._invoke_creator(self)
#     640             pool.logger.debug("Created new connection %r", connection)
#     641             self.connection = connection
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/engine/strategies.py in connect(connection_record)
#     112                         if connection is not None:
#     113                             return connection
# --> 114                 return dialect.connect(*cargs, **cparams)
#     115
#     116             creator = pop_kwarg("creator", connect)
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/engine/default.py in connect(self, *cargs, **cparams)
#     479
#     480     def connect(self, *cargs, **cparams):
# --> 481         return self.dbapi.connect(*cargs, **cparams)
#     482
#     483     def create_connect_args(self, url):
#
# OperationalError: (sqlite3.OperationalError) unable to open database file
# (Background on this error at: http://sqlalche.me/e/e3q8)

# %%
# we will get the table info using the get function
inspector = inspect(engine)
columns = inspector.get_columns('Station')
for color in columns:
    print(color['name'], color['type'])
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/engine/base.py in _wrap_pool_connect(self, fn, connection)
#    2274         try:
# -> 2275             return fn()
#    2276         except dialect.dbapi.Error as e:
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/pool/base.py in unique_connection(self)
#     302         """
# --> 303         return _ConnectionFairy._checkout(self)
#     304
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/pool/base.py in _checkout(cls, pool, threadconns, fairy)
#     759         if not fairy:
# --> 760             fairy = _ConnectionRecord.checkout(pool)
#     761
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/pool/base.py in checkout(cls, pool)
#     491     def checkout(cls, pool):
# --> 492         rec = pool._do_get()
#     493         try:
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/pool/impl.py in _do_get(self)
#     237     def _do_get(self):
# --> 238         return self._create_connection()
#     239
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/pool/base.py in _create_connection(self)
#     307
# --> 308         return _ConnectionRecord(self)
#     309
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/pool/base.py in __init__(self, pool, connect)
#     436         if connect:
# --> 437             self.__connect(first_connect_check=True)
#     438         self.finalize_callback = deque()
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/pool/base.py in __connect(self, first_connect_check)
#     638             self.starttime = time.time()
# --> 639             connection = pool._invoke_creator(self)
#     640             pool.logger.debug("Created new connection %r", connection)
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/engine/strategies.py in connect(connection_record)
#     113                             return connection
# --> 114                 return dialect.connect(*cargs, **cparams)
#     115
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/engine/default.py in connect(self, *cargs, **cparams)
#     480     def connect(self, *cargs, **cparams):
# --> 481         return self.dbapi.connect(*cargs, **cparams)
#     482
#
# OperationalError: unable to open database file
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# <ipython-input-44-d4d04c1d1815> in <module>
#       1 # we will get the table info using the get function
# ----> 2 inspector = inspect(engine)
#       3 columns = inspector.get_columns('Station')
#       4 for color in columns:
#       5     print(color['name'], color['type'])
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/inspection.py in inspect(subject, raiseerr)
#      61             if reg is True:
#      62                 return subject
# ---> 63             ret = reg(subject)
#      64             if ret is not None:
#      65                 break
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/engine/reflection.py in _insp(bind)
#     139     @inspection._inspects(Connectable)
#     140     def _insp(bind):
# --> 141         return Inspector.from_engine(bind)
#     142
#     143     @property
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/engine/reflection.py in from_engine(cls, bind)
#     135         if hasattr(bind.dialect, "inspector"):
#     136             return bind.dialect.inspector(bind)
# --> 137         return Inspector(bind)
#     138
#     139     @inspection._inspects(Connectable)
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/engine/reflection.py in __init__(self, bind)
#     109         if self.engine is bind:
#     110             # if engine, ensure initialized
# --> 111             bind.connect().close()
#     112
#     113         self.dialect = self.engine.dialect
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/engine/base.py in connect(self, **kwargs)
#    2204         """
#    2205
# -> 2206         return self._connection_cls(self, **kwargs)
#    2207
#    2208     @util.deprecated(
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/engine/base.py in __init__(self, engine, connection, close_with_result, _branch_from, _execution_options, _dispatch, _has_events)
#     101                 connection
#     102                 if connection is not None
# --> 103                 else engine.raw_connection()
#     104             )
#     105             self.__transaction = None
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/engine/base.py in raw_connection(self, _connection)
#    2304         """
#    2305         return self._wrap_pool_connect(
# -> 2306             self.pool.unique_connection, _connection
#    2307         )
#    2308
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/engine/base.py in _wrap_pool_connect(self, fn, connection)
#    2277             if connection is None:
#    2278                 Connection._handle_dbapi_exception_noconnection(
# -> 2279                     e, dialect, self
#    2280                 )
#    2281             else:
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/engine/base.py in _handle_dbapi_exception_noconnection(cls, e, dialect, engine)
#    1542             util.raise_from_cause(newraise, exc_info)
#    1543         elif should_wrap:
# -> 1544             util.raise_from_cause(sqlalchemy_exception, exc_info)
#    1545         else:
#    1546             util.reraise(*exc_info)
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/util/compat.py in raise_from_cause(exception, exc_info)
#     396     exc_type, exc_value, exc_tb = exc_info
#     397     cause = exc_value if exc_value is not exception else None
# --> 398     reraise(type(exception), exception, tb=exc_tb, cause=cause)
#     399
#     400
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/util/compat.py in reraise(tp, value, tb, cause)
#     150             value.__cause__ = cause
#     151         if value.__traceback__ is not tb:
# --> 152             raise value.with_traceback(tb)
#     153         raise value
#     154
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/engine/base.py in _wrap_pool_connect(self, fn, connection)
#    2273         dialect = self.dialect
#    2274         try:
# -> 2275             return fn()
#    2276         except dialect.dbapi.Error as e:
#    2277             if connection is None:
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/pool/base.py in unique_connection(self)
#     301
#     302         """
# --> 303         return _ConnectionFairy._checkout(self)
#     304
#     305     def _create_connection(self):
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/pool/base.py in _checkout(cls, pool, threadconns, fairy)
#     758     def _checkout(cls, pool, threadconns=None, fairy=None):
#     759         if not fairy:
# --> 760             fairy = _ConnectionRecord.checkout(pool)
#     761
#     762             fairy._pool = pool
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/pool/base.py in checkout(cls, pool)
#     490     @classmethod
#     491     def checkout(cls, pool):
# --> 492         rec = pool._do_get()
#     493         try:
#     494             dbapi_connection = rec.get_connection()
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/pool/impl.py in _do_get(self)
#     236
#     237     def _do_get(self):
# --> 238         return self._create_connection()
#     239
#     240     def recreate(self):
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/pool/base.py in _create_connection(self)
#     306         """Called by subclasses to create a new ConnectionRecord."""
#     307
# --> 308         return _ConnectionRecord(self)
#     309
#     310     def _invalidate(self, connection, exception=None, _checkin=True):
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/pool/base.py in __init__(self, pool, connect)
#     435         self.__pool = pool
#     436         if connect:
# --> 437             self.__connect(first_connect_check=True)
#     438         self.finalize_callback = deque()
#     439
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/pool/base.py in __connect(self, first_connect_check)
#     637         try:
#     638             self.starttime = time.time()
# --> 639             connection = pool._invoke_creator(self)
#     640             pool.logger.debug("Created new connection %r", connection)
#     641             self.connection = connection
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/engine/strategies.py in connect(connection_record)
#     112                         if connection is not None:
#     113                             return connection
# --> 114                 return dialect.connect(*cargs, **cparams)
#     115
#     116             creator = pop_kwarg("creator", connect)
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/engine/default.py in connect(self, *cargs, **cparams)
#     479
#     480     def connect(self, *cargs, **cparams):
# --> 481         return self.dbapi.connect(*cargs, **cparams)
#     482
#     483     def create_connect_args(self, url):
#
# OperationalError: (sqlite3.OperationalError) unable to open database file
# (Background on this error at: http://sqlalche.me/e/e3q8)

# %%
engine.execute('SELECT * FROM measurement limit 10').fetchall()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/engine/base.py in _wrap_pool_connect(self, fn, connection)
#    2274         try:
# -> 2275             return fn()
#    2276         except dialect.dbapi.Error as e:
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/pool/base.py in connect(self)
#     362         if not self._use_threadlocal:
# --> 363             return _ConnectionFairy._checkout(self)
#     364
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/pool/base.py in _checkout(cls, pool, threadconns, fairy)
#     759         if not fairy:
# --> 760             fairy = _ConnectionRecord.checkout(pool)
#     761
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/pool/base.py in checkout(cls, pool)
#     491     def checkout(cls, pool):
# --> 492         rec = pool._do_get()
#     493         try:
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/pool/impl.py in _do_get(self)
#     237     def _do_get(self):
# --> 238         return self._create_connection()
#     239
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/pool/base.py in _create_connection(self)
#     307
# --> 308         return _ConnectionRecord(self)
#     309
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/pool/base.py in __init__(self, pool, connect)
#     436         if connect:
# --> 437             self.__connect(first_connect_check=True)
#     438         self.finalize_callback = deque()
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/pool/base.py in __connect(self, first_connect_check)
#     638             self.starttime = time.time()
# --> 639             connection = pool._invoke_creator(self)
#     640             pool.logger.debug("Created new connection %r", connection)
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/engine/strategies.py in connect(connection_record)
#     113                             return connection
# --> 114                 return dialect.connect(*cargs, **cparams)
#     115
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/engine/default.py in connect(self, *cargs, **cparams)
#     480     def connect(self, *cargs, **cparams):
# --> 481         return self.dbapi.connect(*cargs, **cparams)
#     482
#
# OperationalError: unable to open database file
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# <ipython-input-45-78ac909d99b4> in <module>
# ----> 1 engine.execute('SELECT * FROM measurement limit 10').fetchall()
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/engine/base.py in execute(self, statement, *multiparams, **params)
#    2176         """
#    2177
# -> 2178         connection = self._contextual_connect(close_with_result=True)
#    2179         return connection.execute(statement, *multiparams, **params)
#    2180
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/engine/base.py in _contextual_connect(self, close_with_result, **kwargs)
#    2237         return self._connection_cls(
#    2238             self,
# -> 2239             self._wrap_pool_connect(self.pool.connect, None),
#    2240             close_with_result=close_with_result,
#    2241             **kwargs
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/engine/base.py in _wrap_pool_connect(self, fn, connection)
#    2277             if connection is None:
#    2278                 Connection._handle_dbapi_exception_noconnection(
# -> 2279                     e, dialect, self
#    2280                 )
#    2281             else:
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/engine/base.py in _handle_dbapi_exception_noconnection(cls, e, dialect, engine)
#    1542             util.raise_from_cause(newraise, exc_info)
#    1543         elif should_wrap:
# -> 1544             util.raise_from_cause(sqlalchemy_exception, exc_info)
#    1545         else:
#    1546             util.reraise(*exc_info)
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/util/compat.py in raise_from_cause(exception, exc_info)
#     396     exc_type, exc_value, exc_tb = exc_info
#     397     cause = exc_value if exc_value is not exception else None
# --> 398     reraise(type(exception), exception, tb=exc_tb, cause=cause)
#     399
#     400
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/util/compat.py in reraise(tp, value, tb, cause)
#     150             value.__cause__ = cause
#     151         if value.__traceback__ is not tb:
# --> 152             raise value.with_traceback(tb)
#     153         raise value
#     154
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/engine/base.py in _wrap_pool_connect(self, fn, connection)
#    2273         dialect = self.dialect
#    2274         try:
# -> 2275             return fn()
#    2276         except dialect.dbapi.Error as e:
#    2277             if connection is None:
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/pool/base.py in connect(self)
#     361         """
#     362         if not self._use_threadlocal:
# --> 363             return _ConnectionFairy._checkout(self)
#     364
#     365         try:
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/pool/base.py in _checkout(cls, pool, threadconns, fairy)
#     758     def _checkout(cls, pool, threadconns=None, fairy=None):
#     759         if not fairy:
# --> 760             fairy = _ConnectionRecord.checkout(pool)
#     761
#     762             fairy._pool = pool
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/pool/base.py in checkout(cls, pool)
#     490     @classmethod
#     491     def checkout(cls, pool):
# --> 492         rec = pool._do_get()
#     493         try:
#     494             dbapi_connection = rec.get_connection()
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/pool/impl.py in _do_get(self)
#     236
#     237     def _do_get(self):
# --> 238         return self._create_connection()
#     239
#     240     def recreate(self):
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/pool/base.py in _create_connection(self)
#     306         """Called by subclasses to create a new ConnectionRecord."""
#     307
# --> 308         return _ConnectionRecord(self)
#     309
#     310     def _invalidate(self, connection, exception=None, _checkin=True):
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/pool/base.py in __init__(self, pool, connect)
#     435         self.__pool = pool
#     436         if connect:
# --> 437             self.__connect(first_connect_check=True)
#     438         self.finalize_callback = deque()
#     439
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/pool/base.py in __connect(self, first_connect_check)
#     637         try:
#     638             self.starttime = time.time()
# --> 639             connection = pool._invoke_creator(self)
#     640             pool.logger.debug("Created new connection %r", connection)
#     641             self.connection = connection
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/engine/strategies.py in connect(connection_record)
#     112                         if connection is not None:
#     113                             return connection
# --> 114                 return dialect.connect(*cargs, **cparams)
#     115
#     116             creator = pop_kwarg("creator", connect)
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/engine/default.py in connect(self, *cargs, **cparams)
#     479
#     480     def connect(self, *cargs, **cparams):
# --> 481         return self.dbapi.connect(*cargs, **cparams)
#     482
#     483     def create_connect_args(self, url):
#
# OperationalError: (sqlite3.OperationalError) unable to open database file
# (Background on this error at: http://sqlalche.me/e/e3q8)

# %% [markdown]
# # Exploratory Climate Analysis

# %%
# Design a query to retrieve the last 12 months of precipitation data and plot the results
# Calculate the date 1 year ago from the last data point in the databass

last_date_data = session.execute("SELECT MAX(date) FROM Measurement").fetchall()
print(last_date_data)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/engine/base.py in _wrap_pool_connect(self, fn, connection)
#    2274         try:
# -> 2275             return fn()
#    2276         except dialect.dbapi.Error as e:
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/pool/base.py in connect(self)
#     362         if not self._use_threadlocal:
# --> 363             return _ConnectionFairy._checkout(self)
#     364
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/pool/base.py in _checkout(cls, pool, threadconns, fairy)
#     759         if not fairy:
# --> 760             fairy = _ConnectionRecord.checkout(pool)
#     761
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/pool/base.py in checkout(cls, pool)
#     491     def checkout(cls, pool):
# --> 492         rec = pool._do_get()
#     493         try:
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/pool/impl.py in _do_get(self)
#     237     def _do_get(self):
# --> 238         return self._create_connection()
#     239
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/pool/base.py in _create_connection(self)
#     307
# --> 308         return _ConnectionRecord(self)
#     309
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/pool/base.py in __init__(self, pool, connect)
#     436         if connect:
# --> 437             self.__connect(first_connect_check=True)
#     438         self.finalize_callback = deque()
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/pool/base.py in __connect(self, first_connect_check)
#     638             self.starttime = time.time()
# --> 639             connection = pool._invoke_creator(self)
#     640             pool.logger.debug("Created new connection %r", connection)
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/engine/strategies.py in connect(connection_record)
#     113                             return connection
# --> 114                 return dialect.connect(*cargs, **cparams)
#     115
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/engine/default.py in connect(self, *cargs, **cparams)
#     480     def connect(self, *cargs, **cparams):
# --> 481         return self.dbapi.connect(*cargs, **cparams)
#     482
#
# OperationalError: unable to open database file
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# <ipython-input-46-f1561b2fab81> in <module>
#       2 # Calculate the date 1 year ago from the last data point in the databass
#       3
# ----> 4 last_date_data = session.execute("SELECT MAX(date) FROM Measurement").fetchall()
#       5 print(last_date_data)
#       6
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/orm/session.py in execute(self, clause, params, mapper, bind, **kw)
#    1266             bind = self.get_bind(mapper, clause=clause, **kw)
#    1267
# -> 1268         return self._connection_for_bind(bind, close_with_result=True).execute(
#    1269             clause, params or {}
#    1270         )
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/orm/session.py in _connection_for_bind(self, engine, execution_options, **kw)
#    1128         if self.transaction is not None:
#    1129             return self.transaction._connection_for_bind(
# -> 1130                 engine, execution_options
#    1131             )
#    1132         else:
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/orm/session.py in _connection_for_bind(self, bind, execution_options)
#     429                     )
#     430             else:
# --> 431                 conn = bind._contextual_connect()
#     432
#     433         if execution_options:
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/engine/base.py in _contextual_connect(self, close_with_result, **kwargs)
#    2237         return self._connection_cls(
#    2238             self,
# -> 2239             self._wrap_pool_connect(self.pool.connect, None),
#    2240             close_with_result=close_with_result,
#    2241             **kwargs
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/engine/base.py in _wrap_pool_connect(self, fn, connection)
#    2277             if connection is None:
#    2278                 Connection._handle_dbapi_exception_noconnection(
# -> 2279                     e, dialect, self
#    2280                 )
#    2281             else:
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/engine/base.py in _handle_dbapi_exception_noconnection(cls, e, dialect, engine)
#    1542             util.raise_from_cause(newraise, exc_info)
#    1543         elif should_wrap:
# -> 1544             util.raise_from_cause(sqlalchemy_exception, exc_info)
#    1545         else:
#    1546             util.reraise(*exc_info)
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/util/compat.py in raise_from_cause(exception, exc_info)
#     396     exc_type, exc_value, exc_tb = exc_info
#     397     cause = exc_value if exc_value is not exception else None
# --> 398     reraise(type(exception), exception, tb=exc_tb, cause=cause)
#     399
#     400
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/util/compat.py in reraise(tp, value, tb, cause)
#     150             value.__cause__ = cause
#     151         if value.__traceback__ is not tb:
# --> 152             raise value.with_traceback(tb)
#     153         raise value
#     154
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/engine/base.py in _wrap_pool_connect(self, fn, connection)
#    2273         dialect = self.dialect
#    2274         try:
# -> 2275             return fn()
#    2276         except dialect.dbapi.Error as e:
#    2277             if connection is None:
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/pool/base.py in connect(self)
#     361         """
#     362         if not self._use_threadlocal:
# --> 363             return _ConnectionFairy._checkout(self)
#     364
#     365         try:
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/pool/base.py in _checkout(cls, pool, threadconns, fairy)
#     758     def _checkout(cls, pool, threadconns=None, fairy=None):
#     759         if not fairy:
# --> 760             fairy = _ConnectionRecord.checkout(pool)
#     761
#     762             fairy._pool = pool
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/pool/base.py in checkout(cls, pool)
#     490     @classmethod
#     491     def checkout(cls, pool):
# --> 492         rec = pool._do_get()
#     493         try:
#     494             dbapi_connection = rec.get_connection()
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/pool/impl.py in _do_get(self)
#     236
#     237     def _do_get(self):
# --> 238         return self._create_connection()
#     239
#     240     def recreate(self):
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/pool/base.py in _create_connection(self)
#     306         """Called by subclasses to create a new ConnectionRecord."""
#     307
# --> 308         return _ConnectionRecord(self)
#     309
#     310     def _invalidate(self, connection, exception=None, _checkin=True):
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/pool/base.py in __init__(self, pool, connect)
#     435         self.__pool = pool
#     436         if connect:
# --> 437             self.__connect(first_connect_check=True)
#     438         self.finalize_callback = deque()
#     439
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/pool/base.py in __connect(self, first_connect_check)
#     637         try:
#     638             self.starttime = time.time()
# --> 639             connection = pool._invoke_creator(self)
#     640             pool.logger.debug("Created new connection %r", connection)
#     641             self.connection = connection
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/engine/strategies.py in connect(connection_record)
#     112                         if connection is not None:
#     113                             return connection
# --> 114                 return dialect.connect(*cargs, **cparams)
#     115
#     116             creator = pop_kwarg("creator", connect)
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/engine/default.py in connect(self, *cargs, **cparams)
#     479
#     480     def connect(self, *cargs, **cparams):
# --> 481         return self.dbapi.connect(*cargs, **cparams)
#     482
#     483     def create_connect_args(self, url):
#
# OperationalError: (sqlite3.OperationalError) unable to open database file
# (Background on this error at: http://sqlalche.me/e/e3q8)

# %%
# Calculate the date one year from the last date in data set.
#prev_year = dt.date(int(last_date_data))- dt.timedelta(days=365)
# Calculate the date one year from the last date in data set.
prev_year = dt.date(2017, 8, 23) - dt.timedelta(days=365)

# %%
last_date_data = session.query(Measurement.date).group_by(Measurement.date).order_by((Measurement.date).desc()).limit(1).all()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-48-4c65b1636958> in <module>
# ----> 1 last_date_data = session.query(Measurement.date).group_by(Measurement.date).order_by((Measurement.date).desc()).limit(1).all()
#
# NameError: name 'Measurement' is not defined

# %%
print(last_date_data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-49-75431fe5dc9d> in <module>
# ----> 1 print(last_date_data)
#
# NameError: name 'last_date_data' is not defined

# %%
# Calculate the date one year from the last date in data set.
prev_year = dt.date(2017, 8, 23) - dt.timedelta(days=365)

# %%
print(prev_year)
# Out:
# 2016-08-23

# %%
#total dates
session.query(func.count(Measurement.date)).all()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-52-db9d56a74e84> in <module>
#       1 #total dates
# ----> 2 session.query(func.count(Measurement.date)).all()
#
# NameError: name 'Measurement' is not defined

# %%
#order_by(Measurement.date.desc().

last_date_data = session.query(Measurement.date).order_by(Measurement.date.desc()).first()
last_date_data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-53-eb948a230910> in <module>
#       1 #order_by(Measurement.date.desc().
#       2
# ----> 3 last_date_data = session.query(Measurement.date).order_by(Measurement.date.desc()).first()
#       4 last_date_data
#
# NameError: name 'Measurement' is not defined

# %%
#earliest date

Earliest_date = session.query(Measurement.date).order_by(Measurement.date).first()
print(Earliest_date)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-54-cd1c2bff194f> in <module>
#       1 #earliest date
#       2
# ----> 3 Earliest_date = session.query(Measurement.date).order_by(Measurement.date).first()
#       4 print(Earliest_date)
#
# NameError: name 'Measurement' is not defined

# %%
#last date

End_Date = last_date_data[0]
print(End_Date)#
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-55-90c0e265bbd5> in <module>
#       1 #last date
#       2
# ----> 3 End_Date = last_date_data[0]
#       4 print(End_Date)#
#
# NameError: name 'last_date_data' is not defined

# %%
#Get the year old date 
struct = dt.date.today()
end_date_dateformat = struct.replace(year = int(End_Date[:4]), month = int(End_Date[5:7]), day = int(End_Date[8:]))
last_date_year = end_date_dateformat-dt.timedelta(days=365)
start_date = last_date_year.strftime("%Y-%m-%d")
print(start_date)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-56-a110e6c5407b> in <module>
#       1 #Get the year old date
#       2 struct = dt.date.today()
# ----> 3 end_date_dateformat = struct.replace(year = int(End_Date[:4]), month = int(End_Date[5:7]), day = int(End_Date[8:]))
#       4 last_date_year = end_date_dateformat-dt.timedelta(days=365)
#       5 start_date = last_date_year.strftime("%Y-%m-%d")
#
# NameError: name 'End_Date' is not defined

# %%
# Perform a query to retrieve the data and precipitation scores???
# Perform a query to retrieve the date and precipitation scores
# results = session.query(Measurement.date, Measurement.prcp).filter(Measurement.date >= prev_year).all()
prcp_data = session.query(Measurement.date, Measurement.prcp).filter(Measurement.date >= prev_year).all()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-57-1e9d9b197edf> in <module>
#       2 # Perform a query to retrieve the date and precipitation scores
#       3 # results = session.query(Measurement.date, Measurement.prcp).filter(Measurement.date >= prev_year).all()
# ----> 4 prcp_data = session.query(Measurement.date, Measurement.prcp).filter(Measurement.date >= prev_year).all()
#
# NameError: name 'Measurement' is not defined

# %%
print(prcp_data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-58-fdb346302696> in <module>
# ----> 1 print(prcp_data)
#
# NameError: name 'prcp_data' is not defined

# %%
# Save the query results as a Pandas DataFrame and set the index to the date column
df = pd.DataFrame(prcp_data, columns=['date', 'precipitation'])
df.set_index(df['date'], inplace=True)
df

# Sort the dataframe by date
# df = df.sort_values("date")
df = df.sort_index()

# Use Pandas Plotting with Matplotlib to plot the data
df.plot(rot=90)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-59-b04c7470ffe2> in <module>
#       1 # Save the query results as a Pandas DataFrame and set the index to the date column
# ----> 2 df = pd.DataFrame(prcp_data, columns=['date', 'precipitation'])
#       3 df.set_index(df['date'], inplace=True)
#       4 df
#       5
#
# NameError: name 'prcp_data' is not defined

# %%
# Use Pandas to calcualte the summary statistics for the precipitation data

df.describe()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-60-cb3994763a7f> in <module>
#       1 # Use Pandas to calcualte the summary statistics for the precipitation data
#       2
# ----> 3 df.describe()
#
# NameError: name 'df' is not defined

# %%
# Design a query to show how many stations are available in this dataset?
session.query(Measurement.station).group_by(Measurement.station).count()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-61-3f2cf8ff533c> in <module>
#       1 # Design a query to show how many stations are available in this dataset?
# ----> 2 session.query(Measurement.station).group_by(Measurement.station).count()
#
# NameError: name 'Measurement' is not defined

# %%
# What are the most active stations? (i.e. what stations have the most rows)?
# List the stations and the counts in descending order.
session.query(Measurement.station, func.count(Measurement.station)).\
                group_by(Measurement.station).\
                order_by(func.count(Measurement.station).desc()).all()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-62-d2461c73dc18> in <module>
#       1 # What are the most active stations? (i.e. what stations have the most rows)?
#       2 # List the stations and the counts in descending order.
# ----> 3 session.query(Measurement.station, func.count(Measurement.station)).\
#       4                 group_by(Measurement.station).\
#       5                 order_by(func.count(Measurement.station).desc()).all()
#
# NameError: name 'Measurement' is not defined

# %%
# Using the station id from the previous query, calculate the lowest temperature recorded, 
# highest temperature recorded, and average temperature of the most active station?
result = session.query(func.min(Measurement.tobs),
                       func.max(Measurement.tobs),
                       func.avg(Measurement.tobs)).filter(Measurement.station == 'USC00519281').all()
print(result)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-63-e3fbfd9a0a97> in <module>
#       1 # Using the station id from the previous query, calculate the lowest temperature recorded,
#       2 # highest temperature recorded, and average temperature of the most active station?
# ----> 3 result = session.query(func.min(Measurement.tobs),
#       4                        func.max(Measurement.tobs),
#       5                        func.avg(Measurement.tobs)).filter(Measurement.station == 'USC00519281').all()
#
# NameError: name 'Measurement' is not defined

# %%
# Choose the station with the highest number of temperature observations.
# Query the last 12 months of temperature observation data for this station and plot the results as a histogram

import datetime as dt
from pandas.plotting import table
prev_year = dt.date(2017, 8, 23) - dt.timedelta(days=365)

results = session.query(Measurement.tobs).\
    filter(Measurement.station == 'USC00519281').\
    filter(Measurement.date >= prev_year).all()
df = pd.DataFrame(results, columns=['tobs'])
df.plot.hist(bins=12)
plt.tight_layout()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-64-f0643654d523> in <module>
#       6 prev_year = dt.date(2017, 8, 23) - dt.timedelta(days=365)
#       7
# ----> 8 results = session.query(Measurement.tobs).\
#       9     filter(Measurement.station == 'USC00519281').\
#      10     filter(Measurement.date >= prev_year).all()
#
# NameError: name 'Measurement' is not defined

# %%
# This function called `calc_temps` will accept start date and end date in the format '%Y-%m-%d' 
# and return the minimum, average, and maximum temperatures for that range of dates
def calc_temps(start_date, end_date):
    """TMIN, TAVG, and TMAX for a list of dates.
    
    Args:
        start_date (string): A date string in the format %Y-%m-%d
        end_date (string): A date string in the format %Y-%m-%d
        
    Returns:
        TMIN, TAVE, and TMAX
    """
    
    return session.query(func.min(Measurement.tobs), func.avg(Measurement.tobs), func.max(Measurement.tobs)).\
        filter(Measurement.date >= start_date).filter(Measurement.date <= end_date).all()

# function usage example
print(calc_temps('2012-02-28', '2012-03-05'))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-65-790a4fe371b5> in <module>
#      16
#      17 # function usage example
# ---> 18 print(calc_temps('2012-02-28', '2012-03-05'))
#
# <ipython-input-65-790a4fe371b5> in calc_temps(start_date, end_date)
#      12     """
#      13
# ---> 14     return session.query(func.min(Measurement.tobs), func.avg(Measurement.tobs), func.max(Measurement.tobs)).\
#      15         filter(Measurement.date >= start_date).filter(Measurement.date <= end_date).all()
#      16
#
# NameError: name 'Measurement' is not defined

# %%
# Use your previous function `calc_temps` to calculate the tmin, tavg, and tmax 
# for your trip using the previous year's data for those same dates.
import datetime as dt

prev_year_start = dt.date(2018, 1, 1) - dt.timedelta(days=365)
prev_year_end = dt.date(2018, 1, 7) - dt.timedelta(days=365)

tmin, tavg, tmax = calc_temps(prev_year_start.strftime("%Y-%m-%d"), prev_year_end.strftime("%Y-%m-%d"))[0]
print(tmin, tavg, tmax)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-66-f8b45e069972> in <module>
#       6 prev_year_end = dt.date(2018, 1, 7) - dt.timedelta(days=365)
#       7
# ----> 8 tmin, tavg, tmax = calc_temps(prev_year_start.strftime("%Y-%m-%d"), prev_year_end.strftime("%Y-%m-%d"))[0]
#       9 print(tmin, tavg, tmax)
#
# <ipython-input-65-790a4fe371b5> in calc_temps(start_date, end_date)
#      12     """
#      13
# ---> 14     return session.query(func.min(Measurement.tobs), func.avg(Measurement.tobs), func.max(Measurement.tobs)).\
#      15         filter(Measurement.date >= start_date).filter(Measurement.date <= end_date).all()
#      16
#
# NameError: name 'Measurement' is not defined
